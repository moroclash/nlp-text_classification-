# %%
import glob
import pandas as pd

# %%
corpus_hadith_path = './Dataset/Hadith/'
corpus_quran_path = './Dataset/Quran/'
csv_files = glob.glob(corpus_hadith_path+'/*.utf8.csv')

# %%
print(csv_files)
len(csv_files)
# Out:
# ['./Dataset/Hadith\\hadith-maliks-muwatta.utf8.csv', './Dataset/Hadith\\hadith-musnad-ahmad-ibn-hanbal.utf8.csv', './Dataset/Hadith\\hadith-sahih-bukhari.utf8.csv', './Dataset/Hadith\\hadith-sahih-muslim.utf8.csv', './Dataset/Hadith\\hadith-sunan-abu-dawud.utf8.csv', './Dataset/Hadith\\hadith-sunan-al-darimi.utf8.csv', './Dataset/Hadith\\hadith-sunan-al-nasai.utf8.csv', './Dataset/Hadith\\hadith-sunan-al-tirmidhi.utf8.csv', './Dataset/Hadith\\hadith-sunan-ibn-maja.utf8.csv']
# 9

# %%
list_data = []
for filename in csv_files:
    single_data = pd.read_csv(filename,delimiter='|')
    list_data.append(single_data)
data = pd.concat(list_data)

# %%
#df.columns = ['الباب', 'رقم الحديث','الحديث']
data.shape
# Out:
# (62076, 27)

# %%
data.iloc[:0,3:4]
# Out:
# Empty DataFrame
# Columns: [1.1]
# Index: []

# %%
hadith_malk =  pd.read_csv(corpus_hadith_path+'/hadith-sahih-bukhari.utf8.csv',delimiter='|')

# %%
hadith_malk.iloc[:0,3:4]
# Out:
# Empty DataFrame
# ...
